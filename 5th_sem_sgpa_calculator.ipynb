# %%
#first try
sub1=int(input("enter marks of BCS501:"))
sub2=int(input("enter marks of BCS502:"))
sub3=int(input("enter marks of BCS503:"))
sub4=int(input("enter marks of BAIL504:"))
sub5=int(input("enter marks of BCD586:"))
sub6=int(input("enter marks of BRMK557:"))
sub7=int(input("enter marks of BCS508:"))
sub8=int(input("enter marks of BAI515A:"))
if (sub1 or sub2 or sub3 or sub4 or sub5 or sub6 or sub7 or sub8)>100 and (sub1 or sub2 or sub3 or sub4 or sub5 or sub6 or sub7 or sub8)<0:
    print("invalid marks")
else:
    total=sub1+sub2+sub3+sub4+sub5+sub6+sub7+sub8
    avg=total/8
    total_credits=22
    grade=1
    gradesum=0
    credits=[4,4,4,1,2,3,1,3]
    marks=[sub1,sub2,sub3,sub4,sub5,sub6,sub7,sub8]
    for i in range(0,len(marks)):
        if marks[i]>=90 and marks[i]<=100:
            grade=10
        elif marks[i]<=89 and marks[i]>=80:
            grade=9
        elif marks[i]<=79 and marks[i]>=70:
            grade=8
        elif marks[i]<=69 and marks[i]>=60:
            grade=7
        elif marks[i]<=59 and marks[i]>=50:
            grade=65
        elif marks[i]<=49 and marks[i]>=40:
            grade=5
        elif marks[i]<=39 and marks[i]>=30:
            grade=4
        elif marks[i]<=29 and marks[i]>=20:
            grade=3
        elif marks[i]<=19 and marks[i]>=10:
            grade=25
        else:
            grade=1
        gradesum+=grade*credits[i]
sgpa=(gradesum)/total_credits
print(sgpa)
if sgpa>=9 and sgpa<=10:
    print('grade A')
elif sgpa>=8 and sgpa<9:
    print('grade B')
elif sgpa>=7 and sgpa<8:
    print('grade C')
elif sgpa>=6 and sgpa<7:
    print('grade D')
elif sgpa>=5 and sgpa<6:
    print('grade E')
else:
    print('Fail')
# Out:
# enter marks of BCS501:95
# enter marks of BCS502:-95
# enter marks of BCS503:85
# enter marks of BAIL504:876
# enter marks of BCD586:563
# enter marks of BRMK557:54
# enter marks of BCS508:48
# enter marks of BAI515A:48
# 13.545454545454545
# Fail

# %%
#final code with all the test cases tested
sub1 = int(input("Enter marks of BCS501: "))
sub2 = int(input("Enter marks of BCS502: "))
sub3 = int(input("Enter marks of BCS503: "))
sub4 = int(input("Enter marks of BAIL504: "))
sub5 = int(input("Enter marks of BCD586: "))
sub6 = int(input("Enter marks of BRMK557: "))
sub7 = int(input("Enter marks of BCS508: "))
sub8 = int(input("Enter marks of BAI515A: "))

marks = [sub1, sub2, sub3, sub4, sub5, sub6, sub7, sub8]
credits = [4, 4, 4, 1, 2, 3, 1, 3]
total_credits = 22

if any(m < 0 or m > 100 for m in marks):
    print("Invalid marks entered")
else:
    gradesum = 0

    for i in range(len(marks)):
        m = marks[i]

        if m >= 90:
            grade = 10
        elif m >= 80:
            grade = 9
        elif m >= 70:
            grade = 8
        elif m >= 60:
            grade = 7
        elif m >= 50:
            grade = 6
        elif m >= 40:
            grade = 5
        elif m >= 30:
            grade = 4
        elif m >= 20:
            grade = 3
        elif m >= 10:
            grade = 2
        else:
            grade = 0

        gradesum += grade * credits[i]

    sgpa = gradesum / total_credits
    print("SGPA:", round(sgpa, 2))

    if sgpa >= 9:
        print("Grade A")
    elif sgpa >= 8:
        print("Grade B")
    elif sgpa >= 7:
        print("Grade C")
    elif sgpa >= 6:
        print("Grade D")
    elif sgpa >= 5:
        print("Grade E")
    else:
        print("Fail")
# Out:
# Enter marks of BCS501: 85
# Enter marks of BCS502: 95
# Enter marks of BCS503: 45
# Enter marks of BAIL504: 49
# Enter marks of BCD586: 75
# Enter marks of BRMK557: 82
# Enter marks of BCS508: 814
# Enter marks of BAI515A: 54
# Invalid marks entered
